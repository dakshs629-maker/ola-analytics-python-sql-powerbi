# %%
import pandas as pd

# %%
Bookings = pd.read_csv("Bookings.csv")

# %%
Bookings
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 0       2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3        2024-07-22 3:15:00   3:15:00  CNR2395710036  Canceled by Customer
# 4        2024-07-02 9:02:00   9:02:00  CNR1797421769               Success
# ...                     ...       ...            ...                   ...
# 103019   2024-07-31 9:06:00   9:06:00  CNR9488489435               Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
# ...

# %%
Bookings['Vehicle_Type']
# Out:
# 0         Prime Sedan
# 1                Bike
# 2           Prime SUV
# 3               eBike
# 4                Mini
#              ...
# 103019     Prime Plus
# 103020           Auto
# 103021      Prime SUV
# 103022          eBike
# 103023           Auto
# Name: Vehicle_Type, Length: 103024, dtype: object

# %%
Bookings['Vehicle_Type'] == 'Prime Sedan'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103019    False
# 103020    False
# 103021    False
# 103022    False
# 103023    False
# Name: Vehicle_Type, Length: 103024, dtype: bool

# %%
Bookings_Prime_Sedan = Bookings.loc[Bookings['Vehicle_Type'] == 'Prime Sedan',  :]

# %%
Bookings_Prime_Sedan
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 0       2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 21      2024-07-08 22:33:00  22:33:00  CNR6013805089               Success
# 33      2024-07-23 12:56:00  12:56:00  CNR9820692957               Success
# 34      2024-07-08 11:52:00  11:52:00  CNR4094067439               Success
# 66       2024-07-01 2:55:00   2:55:00  CNR5758479139               Success
# ...                     ...       ...            ...                   ...
# 102983   2024-07-31 7:32:00   7:32:00  CNR6329226357  Canceled by Customer
# 102985   2024-07-31 5:30:00   5:30:00  CNR5751455739    Canceled by Driver
# 102993   2024-07-31 8:09:00   8:09:00  CNR1109311100      Driver Not Found
# 103016   2024-07-31 9:20:00   9:20:00  CNR3395373353      Driver Not Found
# 103017  2024-07-31 19:34:00  19:34:00  CNR4870774895               Success
#
# ...

# %%
Sorted_Bookings_Prime_Sedan = Bookings_Prime_Sedan.sort_values('Booking_Value', ascending = False)

# %%
Sorted_Bookings_Prime_Sedan
# Out:
#                       Date      Time     Booking_ID      Booking_Status  \
# 64765  2024-07-28 13:54:00  13:54:00  CNR3706593104             Success
# 4797   2024-07-30 16:57:00  16:57:00  CNR6913681615             Success
# 71124  2024-07-16 19:54:00  19:54:00  CNR1989664706             Success
# 20701   2024-07-17 7:46:00   7:46:00  CNR9650710703             Success
# 17809   2024-07-25 2:16:00   2:16:00  CNR8072830009  Canceled by Driver
# ...                    ...       ...            ...                 ...
# 43249  2024-07-18 16:42:00  16:42:00  CNR7322283764             Success
# 7962    2024-07-07 9:05:00   9:05:00  CNR5501330940             Success
# 8052   2024-07-19 16:58:00  16:58:00  CNR5734722840             Success
# 7470    2024-07-26 4:55:00   4:55:00  CNR3019885577    Driver Not Found
# 20676   2024-07-29 4:37:00   4:37:00  CNR1853849444    Driver Not Found
#
#       Customer_ID Vehicle_Type  Pickup_Location  Drop_Location  V_TAT  C_TAT  \
# ...

# %%
Top_5 = Sorted_Bookings_Prime_Sedan.head()

# %%
Top_5
# Out:
#                       Date      Time     Booking_ID      Booking_Status  \
# 64765  2024-07-28 13:54:00  13:54:00  CNR3706593104             Success
# 4797   2024-07-30 16:57:00  16:57:00  CNR6913681615             Success
# 71124  2024-07-16 19:54:00  19:54:00  CNR1989664706             Success
# 20701   2024-07-17 7:46:00   7:46:00  CNR9650710703             Success
# 17809   2024-07-25 2:16:00   2:16:00  CNR8072830009  Canceled by Driver
#
#       Customer_ID Vehicle_Type  Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 64765   CID536592  Prime Sedan          Kengeri      Chickpet  189.0  120.0
# 4797    CID159544  Prime Sedan         KR Puram   Shantinagar   91.0  110.0
# 71124   CID928507  Prime Sedan  Electronic City     Yelahanka  273.0  135.0
# 20701   CID326153  Prime Sedan         Cox Town     Bellandur  287.0   65.0
# 17809   CID120072  Prime Sedan      Frazer Town   Magadi Road    NaN    NaN
#
#        ...      Canceled_Rides_by_Driver Incomplete_Rides  \
# ...

# %%
Sorted_Bookings_Prime_Sedan.iloc[:5]
# Out:
#                       Date      Time     Booking_ID      Booking_Status  \
# 64765  2024-07-28 13:54:00  13:54:00  CNR3706593104             Success
# 4797   2024-07-30 16:57:00  16:57:00  CNR6913681615             Success
# 71124  2024-07-16 19:54:00  19:54:00  CNR1989664706             Success
# 20701   2024-07-17 7:46:00   7:46:00  CNR9650710703             Success
# 17809   2024-07-25 2:16:00   2:16:00  CNR8072830009  Canceled by Driver
#
#       Customer_ID Vehicle_Type  Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 64765   CID536592  Prime Sedan          Kengeri      Chickpet  189.0  120.0
# 4797    CID159544  Prime Sedan         KR Puram   Shantinagar   91.0  110.0
# 71124   CID928507  Prime Sedan  Electronic City     Yelahanka  273.0  135.0
# 20701   CID326153  Prime Sedan         Cox Town     Bellandur  287.0   65.0
# 17809   CID120072  Prime Sedan      Frazer Town   Magadi Road    NaN    NaN
#
#        ...      Canceled_Rides_by_Driver Incomplete_Rides  \
# ...

# %%
Sorted_Bookings_Prime_Sedan.iloc[:5,0:6]
# Out:
#                       Date      Time     Booking_ID      Booking_Status  \
# 64765  2024-07-28 13:54:00  13:54:00  CNR3706593104             Success
# 4797   2024-07-30 16:57:00  16:57:00  CNR6913681615             Success
# 71124  2024-07-16 19:54:00  19:54:00  CNR1989664706             Success
# 20701   2024-07-17 7:46:00   7:46:00  CNR9650710703             Success
# 17809   2024-07-25 2:16:00   2:16:00  CNR8072830009  Canceled by Driver
#
#       Customer_ID Vehicle_Type
# 64765   CID536592  Prime Sedan
# 4797    CID159544  Prime Sedan
# 71124   CID928507  Prime Sedan
# 20701   CID326153  Prime Sedan
# 17809   CID120072  Prime Sedan

# %%
# %matplotlib 
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: inline

# %%
Top_5.plot.bar(x='Customer_ID', y='V_TAT')
# Out:
# <Axes: xlabel='Customer_ID'>

# %%
Top_5.plot.barh(x='Customer_ID',y='Driver_Ratings')
# Out:
# <Axes: ylabel='Customer_ID'>

# %%
Top_5.plot.pie(x='Booking_ID', y='V_TAT')
# Out:
# <Axes: ylabel='V_TAT'>

# %%
Bookings_grouped = Sorted_Bookings_Prime_Sedan.sort_values('Booking_Value', ascending = False).groupby(['Booking_Status']).size()
Bookings_grouped
# Out:
# Booking_Status
# Canceled by Customer    1470
# Canceled by Driver      2591
# Driver Not Found        1437
# Success                 9379
# dtype: int64

# %%
Bookings_grouped = Sorted_Bookings_Prime_Sedan.sort_values('Booking_Value', ascending = False).groupby(['Booking_Status']).count()
Bookings_grouped
# Out:
#                       Date  Time  Booking_ID  Customer_ID  Vehicle_Type  \
# Booking_Status
# Canceled by Customer  1470  1470        1470         1470          1470
# Canceled by Driver    2591  2591        2591         2591          2591
# Driver Not Found      1437  1437        1437         1437          1437
# Success               9379  9379        9379         9379          9379
#
#                       Pickup_Location  Drop_Location  V_TAT  C_TAT  \
# Booking_Status
# Canceled by Customer             1470           1470      0      0
# Canceled by Driver               2591           2591      0      0
# Driver Not Found                 1437           1437      0      0
# Success                          9379           9379   9379   9379
#
#                       Canceled_Rides_by_Customer  Canceled_Rides_by_Driver  \
# Booking_Status
# Canceled by Customer                        1470                         0
# ...

# %%
def Frequent(f):
    return f.iloc[0]

# %%
Bookings_grouped_customagg = Sorted_Bookings_Prime_Sedan.sort_values('Booking_Value', ascending = False).groupby(['Booking_Status']).agg(Frequent)
                                                                                                                            
Bookings_grouped_customagg
# Out:
#                                      Date      Time     Booking_ID  \
# Booking_Status
# Canceled by Customer   2024-07-21 3:32:00   3:32:00  CNR3872657882
# Canceled by Driver     2024-07-25 2:16:00   2:16:00  CNR8072830009
# Driver Not Found       2024-07-31 8:31:00   8:31:00  CNR6098366012
# Success               2024-07-28 13:54:00  13:54:00  CNR3706593104
#
#                      Customer_ID Vehicle_Type   Pickup_Location Drop_Location  \
# Booking_Status
# Canceled by Customer   CID666037  Prime Sedan     Langford Town   Koramangala
# Canceled by Driver     CID120072  Prime Sedan       Frazer Town   Magadi Road
# Driver Not Found       CID308763  Prime Sedan  Ramamurthy Nagar   Magadi Road
# Success                CID536592  Prime Sedan           Kengeri      Chickpet
#
#                       V_TAT  C_TAT Canceled_Rides_by_Customer  \
# Booking_Status
# Canceled by Customer    NaN    NaN          AC is Not working
# ...

# %%
Bookings_grouped_customagg = Sorted_Bookings_Prime_Sedan.sort_values('Booking_Value', ascending = False).groupby(['Booking_Status']).head(3)
                                                                                                                            
Bookings_grouped_customagg
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 64765   2024-07-28 13:54:00  13:54:00  CNR3706593104               Success
# 4797    2024-07-30 16:57:00  16:57:00  CNR6913681615               Success
# 71124   2024-07-16 19:54:00  19:54:00  CNR1989664706               Success
# 17809    2024-07-25 2:16:00   2:16:00  CNR8072830009    Canceled by Driver
# 100063   2024-07-31 8:31:00   8:31:00  CNR6098366012      Driver Not Found
# 3977    2024-07-24 13:36:00  13:36:00  CNR7507723080    Canceled by Driver
# 107      2024-07-15 8:31:00   8:31:00  CNR6012739836      Driver Not Found
# 49609    2024-07-30 4:32:00   4:32:00  CNR2726500582    Canceled by Driver
# 71703    2024-07-21 3:32:00   3:32:00  CNR3872657882  Canceled by Customer
# 82229    2024-07-18 7:02:00   7:02:00  CNR7883848305  Canceled by Customer
# 37996   2024-07-04 15:45:00  15:45:00  CNR4490413146      Driver Not Found
# ...

# %%
Bookings_grouped = Sorted_Bookings_Prime_Sedan.groupby(['Booking_Status']).agg(Total_bookings=('Booking_Value', 'size'),
                                                                                                                               Avg_value=('Booking_Value', 'mean'),
                                                                                                                               Max_value=('Booking_Value', 'max'),
                                                                                                                              Min_value=('Booking_Value','min'))
Bookings_grouped
# Out:
#                       Total_bookings   Avg_value  Max_value  Min_value
# Booking_Status
# Canceled by Customer            1470  553.936735       2985        100
# Canceled by Driver              2591  572.222694       2991        100
# Driver Not Found                1437  541.159360       2989        100
# Success                         9379  556.994349       2999        100

# %%
Sorted_Bookings_Prime_Sedan.shape
# Out:
# (14877, 21)

# %%
#Boolean
Sorted_Bookings_Prime_Sedan.isna()
# Out:
#         Date   Time  Booking_ID  Booking_Status  Customer_ID  Vehicle_Type  \
# 64765  False  False       False           False        False         False
# 4797   False  False       False           False        False         False
# 71124  False  False       False           False        False         False
# 20701  False  False       False           False        False         False
# 17809  False  False       False           False        False         False
# ...      ...    ...         ...             ...          ...           ...
# 43249  False  False       False           False        False         False
# 7962   False  False       False           False        False         False
# 8052   False  False       False           False        False         False
# 7470   False  False       False           False        False         False
# 20676  False  False       False           False        False         False
#
#        Pickup_Location  Drop_Location  V_TAT  C_TAT  ...  \
# ...

# %%
# No. of missing values in each column of data frame
Sorted_Bookings_Prime_Sedan.isna().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                          5498
# C_TAT                          5498
# Canceled_Rides_by_Customer    13407
# Canceled_Rides_by_Driver      12286
# Incomplete_Rides               5498
# Incomplete_Rides_Reason       14266
# Booking_Value                     0
# Payment_Method                 5498
# Ride_Distance                     0
# Driver_Ratings                 5498
# Customer_Rating                5498
# Vehicle Images                    0
# Unnamed: 20                   14877
# dtype: int64

# %%
# Total no. of cells that contain missing data
Sorted_Bookings_Prime_Sedan.isna().sum().sum()
# Out:
# np.int64(87824)

# %%
#Percentage of cells with missing values
total_cells = Sorted_Bookings_Prime_Sedan.shape[0]*Sorted_Bookings_Prime_Sedan.shape[1]
(Sorted_Bookings_Prime_Sedan.isna().sum().sum()/total_cells)*100
# Out:
# np.float64(28.111146320462716)

# %%
Sorted_Bookings_Prime_Sedan = Sorted_Bookings_Prime_Sedan.dropna ()

# %%
# Investigate for duplicates
Sorted_Bookings_Prime_Sedan.duplicated()
# Out:
# 64765    False
# 4797     False
# 71124    False
# 20701    False
# 17809    False
#          ...
# 43249    False
# 7962     False
# 8052     False
# 7470     False
# 20676    False
# Length: 14877, dtype: bool

# %%
# Investigate for duplicates
Sorted_Bookings_Prime_Sedan.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Get the data type of 'Date' column
Sorted_Bookings_Prime_Sedan['Date'].dtype
# Out:
# dtype('O')

# %%
# Get the data type of first entry of Date column
type(Sorted_Bookings_Prime_Sedan['Date'].iloc[0])
# Out:
# str

# %%
# Change 'Date' column datatype to DateTime format
Sorted_Bookings_Prime_Sedan['Date'] = pd.to_datetime(Sorted_Bookings_Prime_Sedan['Date'])

# %%
# Checking Date column after conversion
Sorted_Bookings_Prime_Sedan['Date']
# Out:
# 64765   2024-07-28 13:54:00
# 4797    2024-07-30 16:57:00
# 71124   2024-07-16 19:54:00
# 20701   2024-07-17 07:46:00
# 17809   2024-07-25 02:16:00
#                 ...
# 43249   2024-07-18 16:42:00
# 7962    2024-07-07 09:05:00
# 8052    2024-07-19 16:58:00
# 7470    2024-07-26 04:55:00
# 20676   2024-07-29 04:37:00
# Name: Date, Length: 14877, dtype: datetime64[ns]

# %%
Sorted_Bookings_Prime_Sedan['Booking_Value'].dtype
# Out:
# dtype('int64')

# %%
import seaborn as sn

# %%
sn.countplot(x='Booking_Status', data = Sorted_Bookings_Prime_Sedan)
# Out:
# <Axes: xlabel='Booking_Status', ylabel='count'>

# %%
sn.barplot(x='Booking_Status',y='Booking_Value', data = Sorted_Bookings_Prime_Sedan)
# Out:
# <Axes: xlabel='Booking_Status', ylabel='Booking_Value'>

# %%
sn.barplot(x='Booking_Status',y='Booking_Value', data = Sorted_Bookings_Prime_Sedan, errorbar = None)
# Errorbar is nothing but confidnece interval ci
# Out:
# <Axes: xlabel='Booking_Status', ylabel='Booking_Value'>

# %%
import numpy as np

# %%
plt.hist(Sorted_Bookings_Prime_Sedan['Booking_Value'])
plt.xlabel('Booking Value(in INR)')
# Out:
# Text(0.5, 0, 'Booking Value(in INR)')

# %%
plt.hist(Sorted_Bookings_Prime_Sedan['Booking_Value'], bins = np.arange(0,5000, 350))
plt.xlabel('Booking Value(in INR)')
# Out:
# Text(0.5, 0, 'Booking Value(in INR)')

# %%
plt.scatter(x= Bookings['Booking_Value'], y= Bookings['V_TAT'])
plt.xlabel('Booking Value')
plt.ylabel('V TAT')
# Out:
# Text(0, 0.5, 'V TAT')

# %%
plt.scatter(x= Sorted_Bookings_Prime_Sedan['Booking_Value'], y= Sorted_Bookings_Prime_Sedan['V_TAT'])
plt.xlabel('Booking Value')
plt.ylabel('Vehicle Tunaround Time') 
plt.xlim(0,300)
# Out:
# (0.0, 300.0)

# %%
plt.scatter(x= Sorted_Bookings_Prime_Sedan['Booking_Value'], y= Sorted_Bookings_Prime_Sedan['V_TAT'], s = 10)
plt.xlabel('Booking Value')
plt.ylabel('Vehicle Tunaround Time') 
plt.xlim(0,300)
# Out:
# (0.0, 300.0)
